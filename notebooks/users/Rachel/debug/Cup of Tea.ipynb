# %% [markdown]
# ## Cup of Tea .....
#
# This is a Wardley map of an Cup of tea that is created from data stored in Jira
#
# here is the root issue https://ubuntu-policy.atlassian.net/browse/MAP-8
#
# Here is the Kanban Board to edit the data: https://ubuntu-policy.atlassian.net/secure/RapidBoard.jspa?rapidView=8&projectKey=MAP

# %%
from Maps_Api import Wardley_Map,Jira_Map
Jira_Map('Map-1').show(600)
# Out:
# <img style="_width:100%;height:600px;border:1px solid black" align="left" src="data:image/png;base64,..."/>

# %% [markdown]
# ## This is the view from the Power
#
# The next map shows the `is needed by` path from the Power

# %%
jira_Map = Jira_Map('Map-7')
jira_Map.link_type = 'is needed by'
jira_Map.show(700)
# Out:
# <img style="_width:100%;height:700px;border:1px solid black" align="left" src="data:image/png;base64,..."/>
