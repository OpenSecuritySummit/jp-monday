# %% [markdown]
# # Part 2 - Simpler API and Schema

# %%
## Setup APIs
import sys
sys.path.append('./OSBot-jira/OSBot-GraphDB')
from osbot_graphsv.demo.Demo_Data import Demo_Data
from osbot_graphsv.views.Views_PlantUml import Views_PlantUml
from oss_bot_utils import *
import pandas as pd

demo_data = Demo_Data()
views     = Views_PlantUml(demo_data.graph_sv)

# %%
graph = views.graph_all_nodes()
show_graph(graph)
# Out:
# <img style="border:1px solid black;height:200pt;" align="left" src="data:image/png;base64,..."/>

# %%
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# Out:
# <function oss_bot_utils.show_graph(graph, height=200)>
